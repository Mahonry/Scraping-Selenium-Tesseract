# %%
import pandas as pd
import base64

# %%
url_base = 'https://api.spotify.com/v1'

# %%
ep_artist = '/artists/{id}'

# %%
id_oceransky = '6genEcweKnEZ92TZvdeLFl'

# %%
url = url_base + ep_artist.format(id = id_oceransky)

# %%
import requests

# %%
r = requests.get(url)

# %%
r.status_code #401, no estamos autorizados para acceder a ese endpoint o ese recurso
# Out:
# 401

# %%
r.json()
# Out:
# {'error': {'status': 401, 'message': 'No token provided'}}

# %%
token_url = 'https://accounts.spotify.com/api/token'

# %%
params = {'grant_type':'client_credentials'}

# %%
headers = {'Authorization':'Basic NTc1NTg2MjY0NTMzNDU4ZGE3MDMyYzYyYTRlMzAwMWI6MDg0YzNhYTUwMzg2NGFkZWE1MGE4ZTYxMzA3M2Y2NDE='}

# %%
r = requests.post(token_url, data = params, headers = headers)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'access_token': 'BQCpu2DrFsG6AvwC9haSDX02TDADpLMf-aPsmSr0GQwxxclHV5qymOAMUoF6FdohVpGoDgxr8CjLRe46Z78',
#  'token_type': 'Bearer',
#  'expires_in': 3600,
#  'scope': ''}

# %%
token = r.json()['access_token']

# %% [markdown]
# # Ahora incluimos el token

# %%
header = {'Authorization':'Bearer {}'.format(token)}

# %%
r = requests.get(url, headers = header)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/6genEcweKnEZ92TZvdeLFl'},
#  'followers': {'href': None, 'total': 112617},
#  'genres': ['cantautor',
#   'latin arena pop',
#   'latin pop',
#   'nueva cancion',
#   'trova'],
#  'href': 'https://api.spotify.com/v1/artists/6genEcweKnEZ92TZvdeLFl',
#  'id': '6genEcweKnEZ92TZvdeLFl',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/79b119df344a455c822a97926886e77a39015154',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/c00f0fe1e946ba3a220a70b078e5b8869b7d0945',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/e833b7ed7af66cd232a55340ba12cd2d6c18fd4f',
#    'width': 160}],
#  'name': 'Edgar Oceransky',
#  'popularity': 56,
#  'type': 'artist',
#  'uri': 'spotify:artist:6genEcweKnEZ92TZvdeLFl'}

# %%
url_busqueda = 'https://api.spotify.com/v1/search'

# %%
search_params = {'q':'Edgar-Oceransky', 'type':'artist', 'market':'AR'}

# %%
busqueda = requests.get(url_busqueda, headers = header, params = search_params)

# %%
busqueda.status_code
# Out:
# 200

# %%
busqueda.json()
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Edgar-Oceransky&type=artist&market=AR&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6genEcweKnEZ92TZvdeLFl'},
#     'followers': {'href': None, 'total': 112617},
#     'genres': ['cantautor',
#      'latin arena pop',
#      'latin pop',
#      'nueva cancion',
#      'trova'],
#     'href': 'https://api.spotify.com/v1/artists/6genEcweKnEZ92TZvdeLFl',
#     'id': '6genEcweKnEZ92TZvdeLFl',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/79b119df344a455c822a97926886e77a39015154',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/c00f0fe1e946ba3a220a70b078e5b8869b7d0945',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/e833b7ed7af66cd232a55340ba12cd2d6c18fd4f',
#       'width': 160}],
#     'name': 'Edgar Oceransky',
#     'popularity': 56,
#     'type': 'artist',
# ...

# %%
df = pd.DataFrame(busqueda.json()['artists']['items'])

# %%
df.head()
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/6...
# 1  {'spotify': 'https://open.spotify.com/artist/3...
#
#                          followers  \
# 0  {'href': None, 'total': 112617}
# 1       {'href': None, 'total': 0}
#
#                                               genres  \
# 0  [cantautor, latin arena pop, latin pop, nueva ...
# 1                                                 []
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/6genEcweKnE...  6genEcweKnEZ92TZvdeLFl
# 1  https://api.spotify.com/v1/artists/3MY03mNGLbo...  3MY03mNGLboVsitxWc2QUs
#
#                                               images  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 1                                                 []
#
#                                       name  popularity    type  \
# ...

# %%
df.sort_values(by = 'popularity', ascending = False).iloc[0]['id']
# Out:
# '6genEcweKnEZ92TZvdeLFl'

# %% [markdown]
# # Renovacion del Token

# %%
def get_token(client_id, client_secret):
    enconded = base64.b64encode(bytes(client_id+':'+client_secret, 'utf-8'))
    params = {'grant_type':'client_credentials'}
    header = {'Authorization': 'Basic' + str(enconded, 'utf-8')}
    r = requests.post(token_url, data = params, headers = headers)
    if r.status_code != 200:
        print('Error en la requests', r.json())
        return None
    else:
        print('Token valido por {} segundos'.format(r.json()['expires_in']))
        return r.json()['access_token']

# %%
client_id = '575586264533458da7032c62a4e3001b'
client_secret = '084c3aa503864adea50a8e613073f641'

# %%
token = get_token(client_id, client_secret)
# Out:
# Token valido por 3600 segundos

# %%
header = {'Authorization':'Bearer {}'.format(token)}

# %%
ep_albums = '/artists/{id_album}/albums'

# %%
url_album = url_base + ep_albums.format(id_album = id_oceransky)

# %%
url_album
# Out:
# 'https://api.spotify.com/v1/artists/{id_album}/albums'

# %%
params = {'country':'AR'}

# %%
albums_oceransky = requests.get(url_album, headers = header, params = params)

# %%
albums_oceransky.status_code
# Out:
# 200

# %%
albums_oceransky.json()#['items']
# Out:
# {'href': 'https://api.spotify.com/v1/artists/6genEcweKnEZ92TZvdeLFl/albums?offset=0&limit=20&include_groups=album,single,compilation,appears_on&market=AR',
#  'items': [{'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6genEcweKnEZ92TZvdeLFl'},
#      'href': 'https://api.spotify.com/v1/artists/6genEcweKnEZ92TZvdeLFl',
#      'id': '6genEcweKnEZ92TZvdeLFl',
#      'name': 'Edgar Oceransky',
#      'type': 'artist',
#      'uri': 'spotify:artist:6genEcweKnEZ92TZvdeLFl'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0eDQlGtmwyq67ApA0Yhyfl'},
#      'href': 'https://api.spotify.com/v1/artists/0eDQlGtmwyq67ApA0Yhyfl',
#      'id': '0eDQlGtmwyq67ApA0Yhyfl',
#      'name': 'Diego Ojeda',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eDQlGtmwyq67ApA0Yhyfl'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5ZVOYMDO9TFmtxyhrWV6Wl'},
# ...

# %%
lista_albums = [(album['id'],album['name']) for album in albums_oceransky.json()['items']]
lista_albums
# Out:
# [('5ZVOYMDO9TFmtxyhrWV6Wl', 'Maldita Vocación'),
#  ('59vHnSfYowxJOl9WsfKAHt', 'Sólo / Ni Tan Sólo 2'),
#  ('3WoT3NklGci5s5oQUTcA7V', '#Eometropolitan2019'),
#  ('6rA1049L2CKGxzfkePKhUY', 'Escarlata Live Sessions'),
#  ('3TWcdcy2vPnaIXmDYfCpj0', 'Escarlata'),
#  ('7r5ZXG4iYK4M8wvKN9iPtl', 'El Big Bang'),
#  ('3ZoaBnOej5uIEIQxWtV7Zq', 'N Otra Vida (Edición Especial)'),
#  ('3sRJg8SQuvRG7ocaIUMMO7', 'Pedro Santiago Edgar'),
#  ('0AhSk6ma0o5IC2GLg85PJ6', 'Sólo, Ni Tan Sólo (En Directo)'),
#  ('24whpVCHN2yE2OeH0ONTxH', 'Una Mirada'),
#  ('5cBc3JWmjJ2jNm1eZKixwA', 'Vivo Costa Rica Centroamérica (En Directo)'),
#  ('1d9uwoH7sKtUSY3ND6jVNK', 'Te Seguiré'),
#  ('2VvlDz9IS23XmNMzjeGdLN', 'De Carne y Hueso'),
#  ('0K7m7THvWNmouJuhYjkEIP', 'Estoy aquí'),
#  ('4X6HawmqhHshwuBPuikoPa', 'Oxígeno'),
#  ('3D1RZL6JfSoM5yvV15AEa1', 'Si Estoy Lejos'),
#  ('2WARKoCk4Y8TEuV94dp8qB', 'Tuve'),
#  ('4GuR8TyE037QkZjlM1tmPz', 'Incendio'),
#  ('7EfcMz3q0kOtDz7pusgBCV', 'Quiero Estar'),
# ...

# %%
album_ep = '/albums/{album_id}'
album_params = {'market':'AR'}

# %%
n_otra_vida_id = '3ZoaBnOej5uIEIQxWtV7Zq'

# %%
n_otra_vida = requests.get(url_base + album_ep.format(album_id = n_otra_vida_id + '/tracks'), headers = header, params = params)

# %%
n_otra_vida.json()['items']
# Out:
# [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6genEcweKnEZ92TZvdeLFl'},
#     'href': 'https://api.spotify.com/v1/artists/6genEcweKnEZ92TZvdeLFl',
#     'id': '6genEcweKnEZ92TZvdeLFl',
#     'name': 'Edgar Oceransky',
#     'type': 'artist',
#     'uri': 'spotify:artist:6genEcweKnEZ92TZvdeLFl'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
# ...

# %%
tracks = [(track['id'],track['name']) for track in n_otra_vida.json()['items']]

# %%
tracks
# Out:
# [('6ro3K8XO1H6H5uVDoRuR35', 'N Otra Vida'),
#  ('6RwYC6yU1cwk9G0oi8zNPI', 'Últimamente'),
#  ('064PGPM4RRfF2MlzvnGgJ9', 'Que Se Detenga el Tiempo'),
#  ('3QTv213yYs5h8YmfGEWN3R', 'Hay Algo Que No Sabes'),
#  ('6eAUzXPigOnHGFQ6KaMVfX', 'Una Luna de Miel'),
#  ('4Cvfjti9T53t2dniL91cfZ', 'Otro Día Sin Ti'),
#  ('3bRFMXhM23RPCIBERB3naz', '¿Quién Quiere el Paraíso?'),
#  ('2AvAiLLZly150VXLEIJXw8', 'Te Dejé'),
#  ('31hXH1TeUsh8Ve4uk79dSU', 'Bajándo el Telón'),
#  ('58rmTYe2w5aQz4QqNSwp65', 'Yo Me Quedo'),
#  ('4V2mMhQGo0UWLvGeuO7IKd', 'Te Dejé (Piano Versión) [feat. Edel Juárez]'),
#  ('7mnexkKqw92pw3RwfR0IOU', 'Bajándo el Telón'),
#  ('2wt6SfhOZbTO4WO9NMXZBV',
#   'Yo Me Quedo (Acustic Versión) [feat. Miguel Inzunza, Rodrigo Rojas, Adrián Gil & Edel Juárez]')]

# %%
def obtener_discografia(artist_id, token, return_name = False, page_limit = 50, country = None):
    url = f'https://api.spotify.com/v1/artists/{artist_id}/albums'
    header = {'Authorization': f'Bearer {token}'}
    params = {'limit':page_limit,
             'offset':0,
             'country':country}
    lista = []
    r = requests.get(url, params = params, headers = header)
    
    if r.status_code != 200:
        print('Error en la requests ',r.json())
        return None
    
    if return_name:
        lista += [(item['id'], item['name']) for item in r.json()['items']]
    else:
        lista += [item['id'] for item in r.json()['items']]
    
    while r.json()['next']:
        r = requests.get(r.json()['next'], headers = header)
        if  return_name:
            lista += [(item['id'], item['name']) for item in r.json()['items']]
        else:
            lista += [item['id'] for item in r.json()['items']]
    return lista

# %%
def obtener_tracks(album_id, token, return_name=False, page_limit=50, market=None):
    url=f'https://api.spotify.com/v1/albums/{album_id}/tracks'
    header = {'Authorization': f'Bearer {token}'}
    params = {'limit': page_limit, 
              'offset': 0,
              'market': market}
    lista = []
    r = requests.get(url, params=params, headers=header)
    
    if r.status_code != 200:
        print('Error en request.', r.json())
        return None
    
    if return_name:
        lista += [(item['id'], item['name']) for item in r.json()['items']]
    else:
        lista += [item['id'] for item in r.json()['items']]
        
    while r.json()['next']:
        r = requests.get(r.json()['next'], headers=header) # El resto de los parámetros están dentro de la URL
        if return_name:
            lista += [(item['id'], item['name']) for item in r.json()['items']]
        else:
            lista += [item['id'] for item in r.json()['items']]
    
    return lista

# %%
for album in obtener_discografia(id_oceransky, token, return_name=True):
    print(album[1])
    for track in obtener_tracks(album[0], token, return_name = True):
        print('\t', track[1])
# Out:
# Maldita Vocación
# 	 Tuve
# 	 El Mejor Experimento
# 	 Guapa
# 	 A Veces Quiero Contarte
# 	 La Talla De Tus Vaqueros
# 	 Yo Me Quedo
# 	 Quiero Estar
# 	 Si Estoy Lejos
# 	 Esa Parte De Tu Historia
# 	 Cuéntame
# 	 Ahora
# 	 Medley 1: Historias De Amor / Almohadas En Vela / Porque La Quería / Besos Baratos
# 	 Mi Chica Revolucionaria
# 	 Manhattan
# 	 Te Dejé
# 	 Cómo Te Digo
# 	 Medley 2: Puedo Verte / N Otra Vida Me Gustaría / Volver a Perdernos
# 	 Cosquilleo
# 	 Juro
# 	 Medley 3: Y Véras / Sigo Amándote / Quiero / Un Beso Grande
# 	 Incendio
# 	 Maldita Vocación
# 	 Oxígeno (Acústica)
# 	 Oxígeno
# Sólo / Ni Tan Sólo 2
# 	 N Otra Vida (Acustic Live Version)
# 	 Últimamente (Acustic Live Version)
# 	 Que Se Detenga El Tiempo (Acustic Live Version)
# 	 Hay Algo Que No Sabes (Acustic Live Version)
# 	 Te Lleno De Caricias (Acustic Live Version)
# 	 Quién Quiere El Paraíso (Acustic Live Version)
# 	 Otro Día Sin Ti (Acustic Live Version)
# ...

# %%
preview_url = 'https://p.scdn.co/mp3-preview/b226eb06ff3444db366ab4118d3d3dd423e1ff3a?cid=575586264533458da7032c62a4e3001b'

# %%
preview = requests.get(preview_url)
preview
# Out:
# <Response [200]>

# %%
import IPython.display as ipd

# %%
ipd.Audio(preview.content)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
